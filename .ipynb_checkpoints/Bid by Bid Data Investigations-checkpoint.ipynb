# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from IPython.core.display import HTML
import datetime
import numpy as np
import numpy.ma as ma
import pickle
import matplotlib.cm as cm

# %%
#year = 18
year = 19; w = 543 # w is the mid-season cutoff in stats table

# %%
save = os.getcwd()
save = os.path.join(save,"save")
save = os.path.join(save,str(year))

save_bids = os.path.join(save,'allbids.pickle')

with open(save_bids, 'rb') as f:
    df_bids = pickle.load(f)
    
df_bids['Player'] = df_bids['Player'].str.strip()
df_bids['Level'] = df_bids['Level'].astype(int)
df_bids['Round'] = df_bids['Round'].astype(int)
df_bids['Success'] = df_bids['Success'].astype(bool)
    
save_stats = os.path.join(save,'df.pickle')

with open(save_stats, 'rb') as f:
    df_stats = pickle.load(f)

# %%
#add points last season to bids table by mapping player names using stats table
points_last_list = df_stats['Points Last Season'].fillna(0).tolist()
name_list = df_stats['Name'].tolist()
name_to_points_last = dict(zip(name_list,points_last_list))
df_bids['Points Last Season'] = df_bids['Player'].map(name_to_points_last)

# %%
dfa = df_bids[df_bids['Level'] == 4]
dfa = dfa[dfa['Round'] == 2]
dfa = dfa[dfa['Position'] == "Forward"]
display(HTML(dfa.sort_values(by=['Points Last Season','Player'],ascending=False).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Division</th>
#       <th>Level</th>
#       <th>Round</th>
#       <th>Player</th>
#       <th>Manager</th>
#       <th>Team</th>
#       <th>Position</th>
#       <th>Amount</th>
#       <th>Success</th>
#       <th>Points Last Season</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5569</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Sadio Mane</td>
#       <td>Stuart Clover</td>
#       <td>Fourleaf</td>
#       <td>Forward</td>
#       <td>31.0</td>
#       <td>True</td>
#       <td>107.0</td>
#     </tr>
#     <tr>
#       <th>5570</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Sadio Mane</td>
#       <td>Simon Hutchinson</td>
#       <td>Hutchy's Heros</td>
#       <td>Forward</td>
#       <td>20.0</td>
#       <td>False</td>
#       <td>107.0</td>
#     </tr>
#     <tr>
#       <th>5571</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Sadio Mane</td>
#       <td>Hayyan Ali</td>
#       <td>Ali Athletic</td>
#       <td>Forward</td>
#       <td>16.0</td>
#       <td>False</td>
#       <td>107.0</td>
#     </tr>
#     <tr>
#       <th>5572</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Sadio Mane</td>
#       <td>Mark Morcombe</td>
#       <td>Spanish Giants FC</td>
#       <td>Forward</td>
#       <td>6.5</td>
#       <td>False</td>
#       <td>107.0</td>
#     </tr>
#     <tr>
#       <th>5573</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Sadio Mane</td>
#       <td>Rob Keates</td>
#       <td>Keatesy's Exiles</td>
#       <td>Forward</td>
#       <td>5.0</td>
#       <td>False</td>
#       <td>107.0</td>
#     </tr>
#     <tr>
#       <th>5574</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Sadio Mane</td>
#       <td>Steve Higgins</td>
#       <td>FC Tosta Mista</td>
#       <td>Forward</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>107.0</td>
#     </tr>
#     <tr>
#       <th>5575</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Sadio Mane</td>
#       <td>Asa Bradshaw</td>
#       <td>ABCDE FC</td>
#       <td>Forward</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>107.0</td>
#     </tr>
#     <tr>
#       <th>5576</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Sadio Mane</td>
#       <td>Marijan Junek</td>
#       <td>Zagreb United</td>
#       <td>Forward</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>107.0</td>
#     </tr>
#     <tr>
#       <th>3605</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Raul Jimenez</td>
#       <td>Glyn Edwards</td>
#       <td>Borussia Teeth</td>
#       <td>Forward</td>
#       <td>26.0</td>
#       <td>True</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>3606</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Raul Jimenez</td>
#       <td>Dino Baggio</td>
#       <td>Bentekefriedchicken</td>
#       <td>Forward</td>
#       <td>20.0</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>3607</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Raul Jimenez</td>
#       <td>Mitchell Crynes</td>
#       <td>Mitchacho</td>
#       <td>Forward</td>
#       <td>18.0</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>3608</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Raul Jimenez</td>
#       <td>Grahame Flint</td>
#       <td>Murder on Zidane's Floor</td>
#       <td>Forward</td>
#       <td>10.0</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>3609</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Raul Jimenez</td>
#       <td>Psygnosis</td>
#       <td>Escape from Alcaraz</td>
#       <td>Forward</td>
#       <td>1.5</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>3610</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Raul Jimenez</td>
#       <td>Colin Morris</td>
#       <td>Morris Dancers</td>
#       <td>Forward</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>5579</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Callum Wilson</td>
#       <td>Stuart Clover</td>
#       <td>Fourleaf</td>
#       <td>Forward</td>
#       <td>22.0</td>
#       <td>True</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>5580</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Callum Wilson</td>
#       <td>Mark Morcombe</td>
#       <td>Spanish Giants FC</td>
#       <td>Forward</td>
#       <td>5.5</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>5581</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Callum Wilson</td>
#       <td>Brett Stirling</td>
#       <td>Albino Winning</td>
#       <td>Forward</td>
#       <td>4.5</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>5582</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Callum Wilson</td>
#       <td>Steve Higgins</td>
#       <td>FC Tosta Mista</td>
#       <td>Forward</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>5583</th>
#       <td>4d</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Callum Wilson</td>
#       <td>Marijan Junek</td>
#       <td>Zagreb United</td>
#       <td>Forward</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>95.0</td>
#     </tr>
#     <tr>
#       <th>4256</th>
#       <td>4b</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Roberto Firmino</td>
#       <td>Jim Bridger</td>
#       <td>Burning Bridges</td>
#       <td>Forward</td>
#       <td>20.0</td>
#       <td>True</td>
#       <td>82.0</td>
#     </tr>
#     <tr>
#       <th>4257</th>
#       <td>4b</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Roberto Firmino</td>
#       <td>Diarmid Farquhar</td>
#       <td>xoseˈlwiz tʃila'βert's LDFLB</td>
#       <td>Forward</td>
#       <td>0.5</td>
#       <td>False</td>
#       <td>82.0</td>
#     </tr>
#     <tr>
#       <th>4258</th>
#       <td>4b</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Roberto Firmino</td>
#       <td>Johan Cruijff</td>
#       <td>Queen Elizabeth Lakers</td>
#       <td>Forward</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>82.0</td>
#     </tr>
#     <tr>
#       <th>3611</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Ayoze Perez</td>
#       <td>Mitchell Crynes</td>
#       <td>Mitchacho</td>
#       <td>Forward</td>
#       <td>10.0</td>
#       <td>True</td>
#       <td>76.0</td>
#     </tr>
#     <tr>
#       <th>3612</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Ayoze Perez</td>
#       <td>Grahame Flint</td>
#       <td>Murder on Zidane's Floor</td>
#       <td>Forward</td>
#       <td>0.5</td>
#       <td>False</td>
#       <td>76.0</td>
#     </tr>
#     <tr>
#       <th>3613</th>
#       <td>4a</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Ayoze Perez</td>
#       <td>Colin Morris</td>
#       <td>Morris Dancers</td>
#       <td>Forward</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>76.0</td>
#     </tr>
#     <tr>
#       <th>4985</th>
#       <td>4c</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Ayoze Perez</td>
#       <td>Jason Howlett</td>
#       <td>I Heard it was a Game</td>
#       <td>Forward</td>
#       <td>9.5</td>
#       <td>True</td>
#       <td>76.0</td>
#     </tr>
#     <tr>
#       <th>4986</th>
#       <td>4c</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Ayoze Perez</td>
#       <td>Michael Potts</td>
#       <td>Potts of Gold</td>
#       <td>Forward</td>
#       <td>8.0</td>
#       <td>False</td>
#       <td>76.0</td>
#     </tr>
#     <tr>
#       <th>4987</th>
#       <td>4c</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Ayoze Perez</td>
#       <td>Ian Freeland</td>
#       <td>Adamson Blues</td>
#       <td>Forward</td>
#       <td>7.0</td>
#       <td>False</td>
#       <td>76.0</td>
#     </tr>
#     <tr>
#       <th>4988</th>
#       <td>4c</td>
#       <td>4</td>
#       <td>2</td>
#       <td>Ayoze Perez</td>
#       <td>Merv Thomason</td>
#       <td>Mervellous</td>
#       <td>Forward</td>
#       <td>3.0</td>
#       <td>False</td>
#       <td>76.0</td>
#     </tr>
#     <tr>
#       <th>4989</th>
#       <td>4c<

# %%
spef_bids = df_bids[df_bids.Player=="Pierre-Emeric Aubameyang"].Amount

# %%
pmax = spef_bids.max()
x = 0.01
nums,bins = np.histogram(spef_bids, np.arange(0.5-x,pmax+1-x,0.5))
vals = np.arange(0.5,pmax+0.5,0.5)
c = cm.brg((vals%1)+0.5)
plt.bar(vals,nums,width=0.4,color=c)
# Out:
# <BarContainer object of 70 artists>
