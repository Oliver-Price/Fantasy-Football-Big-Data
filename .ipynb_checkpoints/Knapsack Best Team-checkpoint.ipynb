# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from IPython.core.display import HTML
import datetime
import numpy as np
import numpy.ma as ma
import os

# %%
#year = 18; w = 469
year = 19; w = 543

# %%
save = os.getcwd()
save = os.path.join(save,"save")
save = os.path.join(save,str(year))
save = os.path.join(save,'df_rich.pickle')

with open(save, 'rb') as f:
    df = pickle.load(f)

# %%
df = df.rename(columns={"position":"Position"})

# %%
clubdict = dict(zip(df["club"].unique().tolist(),np.arange(20).tolist()))

# %%
clubdict
# Out:
# {'Burnley': 0,
#  'Manchester Utd': 1,
#  'Tottenham': 2,
#  'Bournemouth': 3,
#  'Liverpool': 4,
#  'Crystal Palace': 5,
#  'Leicester City': 6,
#  'Chelsea': 7,
#  'Southampton': 8,
#  'Everton': 9,
#  'Manchester City': 10,
#  'Arsenal': 11,
#  'Newcastle United': 12,
#  'Brighton & Hove Albion': 13,
#  'Wolverhampton Wanderers': 14,
#  'West Ham United': 15,
#  'Watford': 16,
#  'Norwich City': 17,
#  'Aston Villa': 18,
#  'Sheffield United': 19}

# %% [markdown]
# ## Random Guess

# %%
dfl = df.loc[:w]
rnum = np.random.rand((dfl.shape[0]))
dfl.insert(dfl.shape[1],"rand",rnum,True)
goalies = dfl[dfl['Position'] == "Goalkeeper"]
defenders = dfl[dfl['Position'] == "Defender"]
midfielders = dfl[dfl['Position'] == "Midfielder"]
forwards = dfl[dfl['Position'] == "Forward"]

# %%
randomteam = pd.concat([goalies.nlargest(1,"rand"),defenders.nlargest(4,"rand"),midfielders.nlargest(4,"rand"),forwards.nlargest(2,"rand")])

# %%
np.histogram(randomteam["club"].map(clubdict))[0].max()
# Out:
# 3

# %%
np.sum(randomteam['Highest R1 Bid']+0.5)
# Out:
# 61.5

# %%
np.sum(randomteam['Points'])
# Out:
# 178.0

# %%
bestrandomlist = []
bestpointslist = []
for m in range(10):
    bestrandom = None
    bestpoints = 0
    for n in range(1000):
        dfl = df.loc[:w]
        rnum = np.random.rand((dfl.shape[0]))
        dfl.insert(dfl.shape[1],"rand",rnum,True)
        goalies = dfl[dfl['Position'] == "Goalkeeper"]
        defenders = dfl[dfl['Position'] == "Defender"]
        midfielders = dfl[dfl['Position'] == "Midfielder"]
        forwards = dfl[dfl['Position'] == "Forward"]
        randomteam = pd.concat([goalies.nlargest(1,"rand"),defenders.nlargest(4,"rand"),midfielders.nlargest(4,"rand"),forwards.nlargest(2,"rand")])
        if np.histogram(randomteam["club"].map(clubdict))[0].max() < 3:
            if np.sum(randomteam['Highest R1 Bid']+0.5) <= 75:
                if np.sum(randomteam['Points']) > bestpoints:
                    bestrandom = randomteam
                    bestpoints = np.sum(randomteam['Points'])
    bestrandomlist.append(bestrandom)
    bestpointslist.append(bestpoints)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-024ab40879e6> in <module>
#      12         midfielders = dfl[dfl['Position'] == "Midfielder"]
#      13         forwards = dfl[dfl['Position'] == "Forward"]
# ---> 14         randomteam = pd.concat([goalies.nlargest(1,"rand"),defenders.nlargest(4,"rand"),midfielders.nlargest(4,"rand"),forwards.nlargest(2,"rand")])
#      15         if np.histogram(randomteam["club"].map(clubdict))[0].max() < 3:
#      16             if np.sum(randomteam['Highest R1 Bid']+0.5) <= 75:
#
# C:\PhD\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# C:\PhD\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     424             new_data = concatenate_block_managers(
#     425                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 426                 copy=self.copy)
#     427             if not self.copy:
#     428                 new_data._consolidate_inplace()
#
# C:\PhD\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2059         else:
#    2060             b = make_block(
# -> 2061                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    2062                 placement=placement)
#    2063         blocks.append(b)
#
# C:\PhD\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in concatenate_join_units(join_units, concat_axis, copy)
#     254                 concat_values = concat_values.copy()
#     255     else:
# --> 256         concat_values = _concat._concat_compat(to_concat, axis=concat_axis)
#     257
#     258     return concat_values
#
# C:\PhD\Anaconda3\lib\site-packages\pandas\core\dtypes\concat.py in _concat_compat(to_concat, axis)
#     168                 to_concat = [x.astype('object') for x in to_concat]
#     169
# --> 170     return np.concatenate(to_concat, axis=axis)
#     171
#     172
#
# KeyboardInterrupt:

# %%
allrands = bestrandomlist[0]
for x in range(1,len(bestrandomlist)):
    allrands = pd.concat([allrands,bestrandomlist[x]])

# %%
allrands["Name"].unique().size

# %%
(max(bestpointslist) - min(bestpointslist))/sum(bestpointslist)*len(bestpointslist)*100

# %% [markdown]
# ## Dynamic Programming

# %%
items = df[['Name','Highest R1 Bid','Points']]
items.Points = items.Points.astype(int)
items['Highest R1 Bid'] = items['Highest R1 Bid'].astype(int)*2
# Out:
# C:\PhD\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\PhD\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def knapsack_pandas(items, limit):
    table = np.zeros((items.shape[0]+1,limit+1),dtype=int)
 
    for j in range(1, items.shape[0] + 1):
        item, wt, val = items.iloc[j-1]
        for w in range(1, limit + 1):
            if wt > w:
                table[j][w] = table[j-1][w]
            else:
                table[j][w] = max(table[j-1][w],
                                  table[j-1][w-wt] + val)
 
    result = pd.DataFrame(columns=['item','weight','value'])
    
    w = limit
    for j in range(len(items), 0, -1):
        was_added = table[j][w] != table[j-1][w]
 
        if was_added:
            item, wt, val = items.iloc[j-1]
            result = result.append(items.iloc[j-1])
            w -= wt
            
    return (result, table)

# %%
(bagged, table) = knapsack_pandas(items, 75)
display(HTML(bagged.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item</th>
#       <th>weight</th>
#       <th>value</th>
#       <th>Highest R1 Bid</th>
#       <th>Name</th>
#       <th>Points</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>650</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Jarrod Bowen</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>646</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Sander Berge</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>645</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Bruno Fernandes</td>
#       <td>17.0</td>
#     </tr>
#     <tr>
#       <th>643</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Tomas Soucek</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>642</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Jeremy Ngakia</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>641</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Pablo Mari</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>640</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Steven Bergwijn</td>
#       <td>11.0</td>
#     </tr>
#     <tr>
#       <th>639</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Valentino Lazaro</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>635</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Nabil Bentaleb</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>633</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Mbwana Samatta</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>627</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Lukas Rupp</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>625</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Ondrej Duda</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>624</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Japhet Tanganga</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>618</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>William Smallbone</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>615</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Adam Idah</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>605</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Max Kilman</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>602</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Brandon Williams</td>
#       <td>22.0</td>
#     </tr>
#     <tr>
#       <th>600</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Matthew Longstaff</td>
#       <td>12.0</td>
#     </tr>
#     <tr>
#       <th>598</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Steven Alzate</td>
#       <td>12.0</td>
#     </tr>
#     <tr>
#       <th>596</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Eric Garcia</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>595</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Aaron Connolly</td>
#       <td>17.0</td>
#     </tr>
#     <tr>
#       <th>594</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Billy Gilmour</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>590</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Gabriel Martinelli</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>589</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Aaron Ramsdale</td>
#       <td>22.0</td>
#     </tr>
#     <tr>
#       <th>588</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Kevin Danso</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>586</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Neal Maupay</td>
#       <td>51.0</td>
#     </tr>
#     <tr>
#       <th>585</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Moise Kean</td>
#       <td>12.0</td>
#     </tr>
#     <tr>
#       <th>584</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Oliver McBurnie</td>
#       <td>27.0</td>
#     </tr>
#     <tr>
#       <th>583</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Patrick Cutrone</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>582</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Joelinton</td>
#       <td>34.0</td>
#     </tr>
#     <tr>
#       <th>581</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Jordan Ayew</td>
#       <td>54.0</td>
#     </tr>
#     <tr>
#       <th>580</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Danny Welbeck</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>579</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Andy Carroll</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>578</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Dennis Praet</td>
#       <td>20.0</td>
#     </tr>
#     <tr>
#       <th>577</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Giovani Lo Celso</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Ismaila Sarr</td>
#       <td>36.0</td>
#     </tr>
#     <tr>
#       <th>575</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Ibrahim Amadou</td>
#       <td>8.0</td>
#     </tr>
#     <tr>
#       <th>574</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Jean-Philippe Gbamin</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>572</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Pedro Neto</td>
#       <td>17.0</td>
#     </tr>
#     <tr>
#       <th>571</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Allan Saint-Maximin</td>
#       <td>23.0</td>
#     </tr>
#     <tr>
#       <th>570</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Nicolas Pepe</td>
#       <td>39.0</td>
#     </tr>
#     <tr>
#       <th>569</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Marvelous Nakamba</td>
#       <td>18.0</td>
#     </tr>
#     <tr>
#       <th>568</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Arnaut Danjuma</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>566</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Douglas Luiz</td>
#       <td>31.0</td>
#     </tr>
#     <tr>
#       <th>565</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Dani Ceballos</td>
#       <td>14.0</td>
#     </tr>
#     <tr>
#       <th>564</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Trezeguet</td>
#       <td>26.0</td>
#     </tr>
#     <tr>
#       <th>562</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>Ryan Sessegnon</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>561</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>

# %% [markdown]
# ## Linear Programming

# %%
from scipy.optimize import linprog
dfl = df.iloc[0:w]

# %%
points = dfl['Points']
cost = dfl['Highest R1 Bid']+0.5
gk   = dfl['Position'].apply(lambda x: 1 if x == 'Goalkeeper' else 0)
defe = dfl['Position'].apply(lambda x: 1 if x == 'Defender' else 0)
mid  = dfl['Position'].apply(lambda x: 1 if x == 'Midfielder' else 0)
stri = dfl['Position'].apply(lambda x: 1 if x == 'Forward' else 0)
xi   = np.ones(dfl.shape[0])

# %%
A_upperbounds = np.array([cost])
b_upperbounds = np.array([75])
A_equality = np.array([gk, defe, mid, stri, xi])
b_equality = np.array([1, 4, 4, 2, 11])
bounds = [(0, 1) for x in range(dfl.shape[0])]

# %%
solution = linprog(
    c=-points,
    A_ub=A_upperbounds,
    b_ub=b_upperbounds,
    A_eq=A_equality,
    b_eq=b_equality,
    bounds=bounds
)
# Out:
# C:\PhD\Anaconda3\lib\site-packages\scipy\optimize\_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)

# %%
dfs = dfl[solution.x>0.001]
dfs
# Out:
#                        Name                     club    Position  Played  \
# 48           Dean Henderson           Manchester Utd  Goalkeeper    27.0
# 170  Trent Alexander-Arnold                Liverpool    Defender    28.0
# 199          Caglar Soyuncu           Leicester City    Defender    28.0
# 211            Enda Stevens         Sheffield United    Defender    28.0
# 221          George Baldock         Sheffield United    Defender    28.0
# 301         Kevin de Bruyne          Manchester City  Midfielder    25.0
# 391            Adama Traore  Wolverhampton Wanderers  Midfielder    22.0
# 422           Jack Grealish              Aston Villa  Midfielder    26.0
# 448             Mason Mount                  Chelsea  Midfielder    25.0
# 453           Todd Cantwell             Norwich City  Midfielder    25.0
# 473              Danny Ings              Southampton     Forward    23.0
# 535             Teemu Pukki             Norwich City     Forward    28.0
#
#      Goals  Assists  Clean Sheets  Conceded  Points  Points Last Season  ...  \
# 48     0.0      0.0          10.0      22.0    52.0                 NaN  ...
# 170    2.0     13.0          11.0      21.0    89.0               103.0  ...
# 199    1.0      1.0          10.0      27.0    54.0                 4.0  ...
# 211    2.0      2.0          10.0      25.0    61.0                 NaN  ...
# 221    2.0      4.0          10.0      25.0    65.0                 NaN  ...
# 301    8.0     17.0           NaN       NaN    83.0                23.0  ...
# 391    4.0      7.0           NaN       NaN    48.0                16.0  ...
# 422    7.0      6.0           NaN       NaN    59.0                 NaN  ...
# 448    6.0      5.0           NaN       NaN    53.0                 NaN  ...
# 453    6.0      2.0           NaN       NaN    47.0                 NaN  ...
# 473   15.0      1.0           NaN       NaN    70.0                48.0  ...
# 535   11.0      3.0           NaN       NaN    67.0                 NaN  ...
#
#      Highest R2 Bid  Round 2 Activty  Round 3 Average  Round 3 Bids  \
# 48              2.0             True         2.000000             1
# 170             0.0            False         0.000000             0
# 199             0.5             True         0.000000             0
# 211             3.0             True         0.000000             2
# 221             0.0            False         2.000000             1
# 301            20.0             True         0.000000             0
# 391             5.0             True         0.000000             0
# 422             8.0             True         1.200000             5
# 448             6.0             True         0.000000             0
# 453             0.0            False         0.000000             0
# 473            18.0             True         0.000000             0
# 535             0.0             True         2.583333             6
#
#      Highest R3 Bid  Round 3 Activty  Round 4 Average  Round 4 Bids  \
# 48              2.0             True           0.0000             0
# 170             0.0            False           0.0000             0
# 199             0.0            False           0.0000             0
# 211             0.0             True           0.5000             1
# 221             2.0             True           0.0000             0
# 301             0.0            False           0.0000             0
# 391             0.0            False           0.0000             0
# 422             5.0             True           4.0000             2
# 448             0.0            False           0.0000             1
# 453             0.0            False           0.0000             0
# 473             0.0            False           0.0000             0
# 535             9.5             True           0.0625             8
#
#      Highest R4 Bid  Round 4 Activty
# 48              0.0            False
# 170             0.0            False
# 199             0.0            False
# 211             0.5             True
# 221             0.0            False
# 301             0.0            False
# 391             0.0            False
# 422             8.0             True
# 448             0.0             True
# 453             0.0            False
# 473             0.0            False
# 535             0.5             True
#
# [12 rows x 106 columns]

# %%
solution.x[solution.x>0.001]
# Out:
# array([1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 1.        , 0.52941176, 1.        , 0.47058824,
#        1.        , 1.        ])

# %%
dfs[['Name','Highest R1 Bid']]
# Out:
#                        Name  Highest R1 Bid
# 48           Dean Henderson             5.0
# 170  Trent Alexander-Arnold            21.0
# 199          Caglar Soyuncu             0.0
# 211            Enda Stevens             3.5
# 221          George Baldock             1.0
# 301         Kevin de Bruyne            20.5
# 391            Adama Traore             0.0
# 422           Jack Grealish             8.5
# 448             Mason Mount             1.0
# 453           Todd Cantwell             0.0
# 473              Danny Ings             7.5
# 535             Teemu Pukki             5.5

# %% [markdown]
# ## Integrer Programming

# %%
from pulp import *
dfi = df.iloc[0:w]

# %%
dfi.club.unique()
# Out:
# array(['Burnley', 'Manchester Utd', 'Tottenham', 'Bournemouth',
#        'Liverpool', 'Crystal Palace', 'Leicester City', 'Chelsea',
#        'Southampton', 'Everton', 'Manchester City', 'Arsenal',
#        'Newcastle United', 'Brighton & Hove Albion',
#        'Wolverhampton Wanderers', 'West Ham United', 'Watford',
#        'Norwich City', 'Aston Villa', 'Sheffield United'], dtype=object)

# %%
player = [dfi['Name'][i] for i in range(dfi.shape[0])]
point = {dfi['Name'][i]: dfi['Points'][i] for i in range(dfi.shape[0])} 
cost = {dfi['Name'][i]: dfi['Highest R1 Bid'][i] + 0.5 for i in range(dfi.shape[0])}
gk = {dfi['Name'][i]: 1 if dfi['Position'][i] == 'Goalkeeper' else 0 for i in range(dfi.shape[0])}
defe = {dfi['Name'][i]: 1 if dfi['Position'][i] == 'Defender' else 0 for i in range(dfi.shape[0])}
mid = {dfi['Name'][i]: 1 if dfi['Position'][i] == 'Midfielder' else 0 for i in range(dfi.shape[0])}
stri = {dfi['Name'][i]: 1 if dfi['Position'][i] == 'Forward' else 0 for i in range(dfi.shape[0])}
city = {dfi['Name'][i]: 1 if dfi['club'][i] == 'Manchester City' else 0 for i in range(dfi.shape[0])}
pool = {dfi['Name'][i]: 1 if dfi['club'][i] == 'Liverpool' else 0 for i in range(dfi.shape[0])}
chel = {dfi['Name'][i]: 1 if dfi['club'][i] == 'Chelsea' else 0 for i in range(dfi.shape[0])}
arse = {dfi['Name'][i]: 1 if dfi['club'][i] == 'Arsenal' else 0 for i in range(dfi.shape[0])}
tot = {dfi['Name'][i]: 1 if dfi['club'][i] == 'Tottenham' else 0 for i in range(dfi.shape[0])}
utd = {dfi['Name'][i]: 1 if dfi['club'][i] == 'Manchester Utd' else 0 for i in range(dfi.shape[0])}
bmo = {dfi['Name'][i]: 1 if dfi['club'][i] == 'Bournemouth' else 0 for i in range(dfi.shape[0])}
lei = {dfi['Name'][i]: 1 if dfi['club'][i] == 'Leicester City' else 0 for i in range(dfi.shape[0])}
xi = {dfi['Name'][i]: 1 for i in range(dfi.shape[0])}

# %%
prob = LpProblem("Fantasy Football",LpMaximize)
player_vars = LpVariable.dicts("Players",player,0,1,LpBinary)

# objective function
prob += lpSum([point[i]*player_vars[i] for i in player]), "Total Cost"

# constraint
prob += lpSum([player_vars[i] for i in player]) == 11, "Total 11 Players"
prob += lpSum([cost[i] * player_vars[i] for i in player]) <= 100.0, "Total Cost"
prob += lpSum([gk[i] * player_vars[i] for i in player]) == 1, "Only 1 GK"
prob += lpSum([defe[i] * player_vars[i] for i in player]) == 4, "Less than 4 DEF"
prob += lpSum([mid[i] * player_vars[i] for i in player]) == 4, "Less than 5 MID"
prob += lpSum([stri[i] * player_vars[i] for i in player]) == 2, "Less than 3 STR"

# solve
status = prob.solve()
# Out:
# C:\PhD\Anaconda3\lib\site-packages\pulp\pulp.py:1137: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
names = []
for v in prob.variables():
    if v.varValue>0:
        nv = v.name.split("_")[1:]
        if len(nv) > 2:
            ln = "-".join(nv[-2:])
            ln2 = " ".join(nv[-2:])
        else:
            ln = nv[-1]
        fn = nv[0]
        if fn == ln:
            names.append(fn)
        else:
            names.append(fn + " " + ln)
            try:
                names.append(fn + " " + ln2)
            except:
                pass
names
# Out:
# ['Adama Traore',
#  'Danny Ings',
#  'Dean Henderson',
#  'Enda Stevens',
#  'George Baldock',
#  'Jamie Vardy',
#  'Jonny Evans',
#  'Kevin de-Bruyne',
#  'Kevin de Bruyne',
#  'Mason Mount',
#  'Mason de Bruyne',
#  'Teemu Pukki',
#  'Teemu de Bruyne',
#  'Trent Alexander-Arnold',
#  'Trent Alexander Arnold']

# %%
df_select = dfi[dfi.Name.isin(names)]
df_select
# Out:
#                        Name                     club    Position  Played  \
# 48           Dean Henderson           Manchester Utd  Goalkeeper    27.0
# 82              Jonny Evans           Leicester City    Defender    29.0
# 170  Trent Alexander-Arnold                Liverpool    Defender    28.0
# 211            Enda Stevens         Sheffield United    Defender    28.0
# 221          George Baldock         Sheffield United    Defender    28.0
# 301         Kevin de Bruyne          Manchester City  Midfielder    25.0
# 391            Adama Traore  Wolverhampton Wanderers  Midfielder    22.0
# 448             Mason Mount                  Chelsea  Midfielder    25.0
# 473              Danny Ings              Southampton     Forward    23.0
# 474             Jamie Vardy           Leicester City     Forward    25.0
# 535             Teemu Pukki             Norwich City     Forward    28.0
#
#      Goals  Assists  Clean Sheets  Conceded  Points  Points Last Season  ...  \
# 48     0.0      0.0          10.0      22.0    52.0                 NaN  ...
# 82     1.0      2.0          10.0      28.0    57.0                35.0  ...
# 170    2.0     13.0          11.0      21.0    89.0               103.0  ...
# 211    2.0      2.0          10.0      25.0    61.0                 NaN  ...
# 221    2.0      4.0          10.0      25.0    65.0                 NaN  ...
# 301    8.0     17.0           NaN       NaN    83.0                23.0  ...
# 391    4.0      7.0           NaN       NaN    48.0                16.0  ...
# 448    6.0      5.0           NaN       NaN    53.0                 NaN  ...
# 473   15.0      1.0           NaN       NaN    70.0                48.0  ...
# 474   19.0      5.0           NaN       NaN    92.0                93.0  ...
# 535   11.0      3.0           NaN       NaN    67.0                 NaN  ...
#
#      Highest R2 Bid  Round 2 Activty  Round 3 Average  Round 3 Bids  \
# 48              2.0             True         2.000000             1
# 82              2.0             True         3.000000             6
# 170             0.0            False         0.000000             0
# 211             3.0             True         0.000000             2
# 221             0.0            False         2.000000             1
# 301            20.0             True         0.000000             0
# 391             5.0             True         0.000000             0
# 448             6.0             True         0.000000             0
# 473            18.0             True         0.000000             0
# 474            41.5             True         0.000000             0
# 535             0.0             True         2.583333             6
#
#      Highest R3 Bid  Round 3 Activty  Round 4 Average  Round 4 Bids  \
# 48              2.0             True           0.0000             0
# 82              8.0             True           0.0000             4
# 170             0.0            False           0.0000             0
# 211             0.0             True           0.5000             1
# 221             2.0             True           0.0000             0
# 301             0.0            False           0.0000             0
# 391             0.0            False           0.0000             0
# 448             0.0            False           0.0000             1
# 473             0.0            False           0.0000             0
# 474             0.0            False           0.0000             0
# 535             9.5             True           0.0625             8
#
#      Highest R4 Bid  Round 4 Activty
# 48              0.0            False
# 82              0.0             True
# 170             0.0            False
# 211             0.5             True
# 221             0.0            False
# 301             0.0            False
# 391             0.0            False
# 448             0.0             True
# 473             0.0            False
# 474             0.0            False
# 535             0.5             True
#
# [11 rows x 106 columns]

# %%
df_select["Bought for"] = df_select['Highest R1 Bid'] + 0.5
df_select[["Name","club","Position","Points","Bought for"]]
# Out:
# C:\PhD\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Name                     club    Position  Points  \
# 48           Dean Henderson           Manchester Utd  Goalkeeper    52.0
# 82              Jonny Evans           Leicester City    Defender    57.0
# 170  Trent Alexander-Arnold                Liverpool    Defender    89.0
# 211            Enda Stevens         Sheffield United    Defender    61.0
# 221          George Baldock         Sheffield United    Defender    65.0
# 301         Kevin de Bruyne          Manchester City  Midfielder    83.0
# 391            Adama Traore  Wolverhampton Wanderers  Midfielder    48.0
# 448             Mason Mount                  Chelsea  Midfielder    53.0
# 473              Danny Ings              Southampton     Forward    70.0
# 474             Jamie Vardy           Leicester City     Forward    92.0
# 535             Teemu Pukki             Norwich City     Forward    67.0
#
#      Bought for
# 48          5.5
# 82          4.5
# 170        21.5
# 211         4.0
# 221         1.5
# 301        21.0
# 391         0.5
# 448         1.5
# 473         8.0
# 474        26.0
# 535         6.0

# %%
df_select.Points.sum()
# Out:
# 737.0

# %%
df_select["Bought for"].sum()
# Out:
# 100.0
